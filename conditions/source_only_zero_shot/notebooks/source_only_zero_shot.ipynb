# %% [markdown]
# # Source-only Strict Zero-shot
# Supporting notebook. No cells have been executed during scaffolding.

# %%
from conditions.source_only_zero_shot.models import SourceOnlyPoseModel
# Data loading, training, and evaluation cells are added after exploration approval.
